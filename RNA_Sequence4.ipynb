# %% [markdown]
# <a href="https://colab.research.google.com/github/elangbijak4/Riset-Bioinformatika/blob/main/RNA_Sequence4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import math
import itertools
from itertools import product
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram

def gap_combinations(seq_lengths, total_gaps):
    alignment_length = sum(seq_lengths) + total_gaps
    total_combinations = math.comb(alignment_length, total_gaps)
    return total_combinations

def generate_combinations(seq1, seq2, total_gaps):
    # Generate all gap positions
    gaps = ['-' for _ in range(total_gaps)]
    seq1_list = list(seq1) + gaps
    seq2_list = list(seq2) + gaps

    # All permutations of gaps in sequences
    seq1_perms = set(itertools.permutations(seq1_list))
    seq2_perms = set(itertools.permutations(seq2_list))

    # Generate all possible alignments
    alignments = list(product(seq1_perms, seq2_perms))

    return alignments

def plot_alignment(alignment):
    seq1, seq2 = alignment
    fig, ax = plt.subplots(figsize=(12, 2))
    ax.text(0.5, 0.7, "".join(seq1), fontsize=12, ha='center', va='center', family='monospace')
    ax.text(0.5, 0.3, "".join(seq2), fontsize=12, ha='center', va='center', family='monospace')
    ax.axis('off')
    plt.show()

def calculate_alignment_score(seq1, seq2, match_score=1, mismatch_penalty=-1, gap_penalty=-2):
    score = 0
    for a, b in zip(seq1, seq2):
        if a == '-' or b == '-':
            score += gap_penalty
        elif a == b:
            score += match_score
        else:
            score += mismatch_penalty
    return score

def identify_conserved_motifs(alignments):
    # Find motifs that are conserved across all alignments
    conserved_positions = []
    for i in range(len(alignments[0][0])):
        column = [alignment[0][i] for alignment in alignments]
        if len(set(column)) == 1:  # All characters in the column are the same
            conserved_positions.append((i, column[0]))
    return conserved_positions

def calculate_evolutionary_distance(seq1, seq2):
    differences = sum(1 for a, b in zip(seq1, seq2) if a != b and a != '-' and b != '-')
    total = sum(1 for a, b in zip(seq1, seq2) if a != '-' and b != '-')
    p = differences / total
    return -3/4 * np.log(1 - 4/3 * p)

def reconstruct_phylogenetic_tree(distances, labels):
    linked = linkage(distances, 'single')
    dendrogram(linked, labels=labels)
    plt.title('Phylogenetic Tree')
    plt.show()

# Example inputs
seq1 = "AUGCU"
seq2 = "AUCG"
total_gaps = 2

# Compute total combinations
seq_lengths = [len(seq1), len(seq2)]
combinations = gap_combinations(seq_lengths, total_gaps)
print(f"Total kombinasi gap: {combinations}")

# Generate and visualize combinations
alignments = generate_combinations(seq1, seq2, total_gaps)
print(f"Total alignments generated: {len(alignments)}")

# Display first 5 alignments
for i, alignment in enumerate(alignments[:5]):
    print(f"Alignment {i + 1}:")
    print("Seq1:", "".join(alignment[0]))
    print("Seq2:", "".join(alignment[1]))
    plot_alignment(alignment)

# Scoring alignments
print("\nScoring Alignments:")
for i, alignment in enumerate(alignments[:5]):
    score = calculate_alignment_score(alignment[0], alignment[1])
    print(f"Alignment {i + 1} score: {score}")

# Identify conserved motifs
conserved_motifs = identify_conserved_motifs(alignments[:5])
print("\nConserved Motifs:")
print(conserved_motifs)

# Evolutionary distances
print("\nEvolutionary Distances:")
distances = []
labels = []
for i, alignment in enumerate(alignments[:5]):
    seq1, seq2 = alignment
    distance = calculate_evolutionary_distance(seq1, seq2)
    distances.append(distance)
    labels.append(f"Alignment {i + 1}")
    print(f"Alignment {i + 1} distance: {distance}")

# Phylogenetic Tree
print("\nReconstructing Phylogenetic Tree:")
reconstruct_phylogenetic_tree(distances, labels)
# Out:
# Total kombinasi gap: 55
# Total alignments generated: 453600
# Alignment 1:
# Seq1: -UGCU-A
# Seq2: AU-CG-
# Alignment 2:
# Seq1: -UGCU-A
# Seq2: GAU-C-
# Alignment 3:
# Seq1: -UGCU-A
# Seq2: UAC--G
# Alignment 4:
# Seq1: -UGCU-A
# Seq2: GC-AU-
# Alignment 5:
# Seq1: -UGCU-A
# Seq2: U-ACG-
# Scoring Alignments:
# Alignment 1 score: -5
# Alignment 2 score: -9
# Alignment 3 score: -10
# Alignment 4 score: -7
# Alignment 5 score: -7
#
# Conserved Motifs:
# [(0, '-'), (1, 'U'), (2, 'G'), (3, 'C'), (4, 'U'), (5, '-'), (6, 'A')]
#
# Evolutionary Distances:
# Alignment 1 distance: 0.4408399986765892
# Alignment 2 distance: nan
# Alignment 3 distance: nan
# Alignment 4 distance: 1.6479184330021643
# Alignment 5 distance: 1.6479184330021643
#
# Reconstructing Phylogenetic Tree:
# <ipython-input-2-11ad817a5ec2>:62: RuntimeWarning: invalid value encountered in log
#   return -3/4 * np.log(1 - 4/3 * p)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-11ad817a5ec2> in <cell line: 115>()
#     113 # Phylogenetic Tree
#     114 print("\nReconstructing Phylogenetic Tree:")
# --> 115 reconstruct_phylogenetic_tree(distances, labels)
#
# <ipython-input-2-11ad817a5ec2> in reconstruct_phylogenetic_tree(distances, labels)
#      63
#      64 def reconstruct_phylogenetic_tree(distances, labels):
# ---> 65     linked = linkage(distances, 'single')
#      66     dendrogram(linked, labels=labels)
#      67     plt.title('Phylogenetic Tree')
#
# /usr/local/lib/python3.10/dist-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1014
#    1015     if y.ndim == 1:
# -> 1016         distance.is_valid_y(y, throw=True, name='y')
#    1017     elif y.ndim == 2:
#    1018         if (y.shape[0] == y.shape[1] and np.allclose(np.diag(y), 0) and
#
# /usr/local/lib/python3.10/dist-packages/scipy/spatial/distance.py in is_valid_y(y, warning, throw, name)
#    2527         if (d * (d - 1) / 2) != n:
#    2528             if name:
# -> 2529                 raise ValueError(('Length n of condensed distance matrix '
#    2530                                   '\'%s\' must be a binomial coefficient, i.e.'
#    2531                                   'there must be a k such that '
#
# ValueError: Length n of condensed distance matrix 'y' must be a binomial coefficient, i.e.there must be a k such that (k \choose 2)=n)!

# %%
import math
import itertools
from itertools import product
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram

# ... (rest of the functions remain the same) ...

def gap_combinations(seq_lengths, total_gaps):
    alignment_length = sum(seq_lengths) + total_gaps
    total_combinations = math.comb(alignment_length, total_gaps)
    return total_combinations

def generate_combinations(seq1, seq2, total_gaps):
    # Generate all gap positions
    gaps = ['-' for _ in range(total_gaps)]
    seq1_list = list(seq1) + gaps
    seq2_list = list(seq2) + gaps

    # All permutations of gaps in sequences
    seq1_perms = set(itertools.permutations(seq1_list))
    seq2_perms = set(itertools.permutations(seq2_list))

    # Generate all possible alignments
    alignments = list(product(seq1_perms, seq2_perms))

    return alignments

def plot_alignment(alignment):
    seq1, seq2 = alignment
    fig, ax = plt.subplots(figsize=(12, 2))
    ax.text(0.5, 0.7, "".join(seq1), fontsize=12, ha='center', va='center', family='monospace')
    ax.text(0.5, 0.3, "".join(seq2), fontsize=12, ha='center', va='center', family='monospace')
    ax.axis('off')
    plt.show()

def calculate_alignment_score(seq1, seq2, match_score=1, mismatch_penalty=-1, gap_penalty=-2):
    score = 0
    for a, b in zip(seq1, seq2):
        if a == '-' or b == '-':
            score += gap_penalty
        elif a == b:
            score += match_score
        else:
            score += mismatch_penalty
    return score

def identify_conserved_motifs(alignments):
    # Find motifs that are conserved across all alignments
    conserved_positions = []
    for i in range(len(alignments[0][0])):
        column = [alignment[0][i] for alignment in alignments]
        if len(set(column)) == 1:  # All characters in the column are the same
            conserved_positions.append((i, column[0]))
    return conserved_positions

def calculate_evolutionary_distance(seq1, seq2):
    differences = sum(1 for a, b in zip(seq1, seq2) if a != b and a != '-' and b != '-')
    total = sum(1 for a, b in zip(seq1, seq2) if a != '-' and b != '-')
    p = differences / total
    return -3/4 * np.log(1 - 4/3 * p)

def reconstruct_phylogenetic_tree(distances, labels):
    linked = linkage(distances, 'single')
    dendrogram(linked, labels=labels)
    plt.title('Phylogenetic Tree')
    plt.show()

# Example inputs
seq1 = "AUGCU"
seq2 = "AUCG"
total_gaps = 2

# ... (rest of the code remains the same) ...

# Compute total combinations
seq_lengths = [len(seq1), len(seq2)]
combinations = gap_combinations(seq_lengths, total_gaps)
print(f"Total kombinasi gap: {combinations}")

# Generate and visualize combinations
alignments = generate_combinations(seq1, seq2, total_gaps)
print(f"Total alignments generated: {len(alignments)}")

# Display first 5 alignments
for i, alignment in enumerate(alignments[:5]):
    print(f"Alignment {i + 1}:")
    print("Seq1:", "".join(alignment[0]))
    print("Seq2:", "".join(alignment[1]))
    plot_alignment(alignment)

# Scoring alignments
print("\nScoring Alignments:")
for i, alignment in enumerate(alignments[:5]):
    score = calculate_alignment_score(alignment[0], alignment[1])
    print(f"Alignment {i + 1} score: {score}")

# Identify conserved motifs
conserved_motifs = identify_conserved_motifs(alignments[:5])
print("\nConserved Motifs:")
print(conserved_motifs)

# Evolutionary distances
print("\nEvolutionary Distances:")
distances = []
labels = []
num_alignments = len(alignments)  # Consider all alignments instead of just 5

# Calculate pairwise distances for all alignments
for i in range(num_alignments):
    for j in range(i + 1, num_alignments):
        seq1, seq2 = alignments[i]  # Extract sequences from alignment i
        seq3, seq4 = alignments[j]  # Extract sequences from alignment j
        distance = calculate_evolutionary_distance(seq1, seq3) # Compare seq1 from alignment i to seq1 from alignment j
        distances.append(distance)
        labels.append(f"Alignment {i + 1} vs Alignment {j + 1}")  # Update labels for pairwise comparisons
        print(f"Alignment {i + 1} vs Alignment {j + 1} distance: {distance}")

# Reshape distances into a condensed distance matrix
num_items = num_alignments
distances = np.array(distances)
# Check if distances array needs reshaping:
# The following condition is True if the distances array is not in condensed form
if distances.ndim == 1 and distances.shape[0] != num_items * (num_items - 1) // 2:
    distances = distances[:num_items * (num_items - 1) // 2]
# No need to reshape if the distances array is already in condensed form

# Phylogenetic Tree
print("\nReconstructing Phylogenetic Tree:")
reconstruct_phylogenetic_tree(distances, labels[:num_items * (num_items - 1) // 2])
# Out:
# Total kombinasi gap: 55
# Total alignments generated: 453600
# Alignment 1:
# Seq1: -UGCU-A
# Seq2: AU-CG-
# Alignment 2:
# Seq1: -UGCU-A
# Seq2: GAU-C-
# Alignment 3:
# Seq1: -UGCU-A
# Seq2: UAC--G
# Alignment 4:
# Seq1: -UGCU-A
# Seq2: GC-AU-
# Alignment 5:
# Seq1: -UGCU-A
# Seq2: U-ACG-
# Scoring Alignments:
# Alignment 1 score: -5
# Alignment 2 score: -9
# Alignment 3 score: -10
# Alignment 4 score: -7
# Alignment 5 score: -7
#
# Conserved Motifs:
# [(0, '-'), (1, 'U'), (2, 'G'), (3, 'C'), (4, 'U'), (5, '-'), (6, 'A')]
#
# Evolutionary Distances:
# Alignment 1 vs Alignment 2 distance: -0.0
# Alignment 1 vs Alignment 3 distance: -0.0
# Alignment 1 vs Alignment 4 distance: -0.0
# Alignment 1 vs Alignment 5 distance: -0.0
# Alignment 1 vs Alignment 6 distance: -0.0
# Alignment 1 vs Alignment 7 distance: -0.0
# Alignment 1 vs Alignment 8 distance: -0.0
# Alignment 1 vs Alignment 9 distance: -0.0
# Alignment 1 vs Alignment 10 distance: -0.0
# Alignment 1 vs Alignment 11 distance: -0.0
# Alignment 1 vs Alignment 12 distance: -0.0
# Alignment 1 vs Alignment 13 distance: -0.0
# Alignment 1 vs Alignment 14 distance: -0.0
# Alignment 1 vs Alignment 15 distance: -0.0
# Alignment 1 vs Alignment 16 distance: -0.0
# Alignment 1 vs Alignment 17 distance: -0.0
# Alignment 1 vs Alignment 18 distance: -0.0
# Alignment 1 vs Alignment 19 distance: -0.0
# Alignment 1 vs Alignment 20 distance: -0.0
# Alignment 1 vs Alignment 21 distance: -0.0
# Alignment 1 vs Alignment 22 distance: -0.0
# Alignment 1 vs Alignment 23 distance: -0.0
# Alignment 1 vs Alignment 24 distance: -0.0
# Alignment 1 vs Alignment 25 distance: -0.0
# Alignment 1 vs Alignment 26 distance: -0.0
# Alignment 1 vs Alignment 27 distance: -0.0
# Alignment 1 vs Alignment 28 distance: -0.0
# Alignment 1 vs Alignment 29 distance: -0.0
# Alignment 1 vs Alignment 30 distance: -0.0
# Alignment 1 vs Alignment 31 distance: -0.0
# Alignment 1 vs Alignment 32 distance: -0.0
# Alignment 1 vs Alignment 33 distance: -0.0
# Alignment 1 vs Alignment 34 distance: -0.0
# Alignment 1 vs Alignment 35 distance: -0.0
# Alignment 1 vs Alignment 36 distance: -0.0
# Alignment 1 vs Alignment 37 distance: -0.0
# Alignment 1 vs Alignment 38 distance: -0.0
# Alignment 1 vs Alignment 39 distance: -0.0
# Alignment 1 vs Alignment 40 distance: -0.0
# Alignment 1 vs Alignment 41 distance: -0.0
# Alignment 1 vs Alignment 42 distance: -0.0
# Alignment 1 vs Alignment 43 distance: -0.0
# Alignment 1 vs Alignment 44 distance: -0.0
# Alignment 1 vs Alignment 45 distance: -0.0
# Alignment 1 vs Alignment 46 distance: -0.0
# Alignment 1 vs Alignment 47 distance: -0.0
# Alignment 1 vs Alignment 48 distance: -0.0
# Alignment 1 vs Alignment 49 distance: -0.0
# Alignment 1 vs Alignment 50 distance: -0.0
# Alignment 1 vs Alignment 51 distance: -0.0
# Alignment 1 vs Alignment 52 distance: -0.0
# Alignment 1 vs Alignment 53 distance: -0.0
# Alignment 1 vs Alignment 54 distance: -0.0
# Alignment 1 vs Alignment 55 distance: -0.0
# Alignment 1 vs Alignment 56 distance: -0.0
# Alignment 1 vs Alignment 57 distance: -0.0
# Alignment 1 vs Alignment 58 distance: -0.0
# Alignment 1 vs Alignment 59 distance: -0.0
# Alignment 1 vs Alignment 60 distance: -0.0
# Alignment 1 vs Alignment 61 distance: -0.0
# Alignment 1 vs Alignment 62 distance: -0.0
# Alignment 1 vs Alignment 63 distance: -0.0
# Alignment 1 vs Alignment 64 distance: -0.0
# Alignment 1 vs Alignment 65 distance: -0.0
# Alignment 1 vs Alignment 66 distance: -0.0
# Alignment 1 vs Alignment 67 distance: -0.0
# Alignment 1 vs Alignment 68 distance: -0.0
# Alignment 1 vs Alignment 69 distance: -0.0
# Alignment 1 vs Alignment 70 distance: -0.0
# Alignment 1 vs Alignment 71 distance: -0.0
# Alignment 1 vs Alignment 72 distance: -0.0
# Alignment 1 vs Alignment 73 distance: -0.0
# Alignment 1 vs Alignment 74 distance: -0.0
# Alignment 1 vs Alignment 75 distance: -0.0
# Alignment 1 vs Alignment 76 distance: -0.0
# Alignment 1 vs Alignment 77 distance: -0.0
# Alignment 1 vs Alignment 78 distance: -0.0
# Alignment 1 vs Alignment 79 distance: -0.0
# Alignment 1 vs Alignment 80 distance: -0.0
# Alignment 1 vs Alignment 81 distance: -0.0
# Alignment 1 vs Alignment 82 distance: -0.0
# Alignment 1 vs Alignment 83 distance: -0.0
# Alignment 1 vs Alignment 84 distance: -0.0
# Alignment 1 vs Alignment 85 distance: -0.0
# Alignment 1 vs Alignment 86 distance: -0.0
# Alignment 1 vs Alignment 87 distance: -0.0
# Alignment 1 vs Alignment 88 distance: -0.0
# Alignment 1 vs Alignment 89 distance: -0.0
# Alignment 1 vs Alignment 90 distance: -0.0
# Alignment 1 vs Alignment 91 distance: -0.0
# Alignment 1 vs Alignment 92 distance: -0.0
# Alignment 1 vs Alignment 93 distance: -0.0
# Alignment 1 vs Alignment 94 distance: -0.0
# Alignment 1 vs Alignment 95 distance: -0.0
# Alignment 1 vs Alignment 96 distance: -0.0
# Alignment 1 vs Alignment 97 distance: -0.0
# Alignment 1 vs Alignment 98 distance: -0.0
# Alignment 1 vs Alignment 99 distance: -0.0
# Alignment 1 vs Alignment 100 distance: -0.0
# Alignment 1 vs Alignment 101 distance: -0.0
# Alignment 1 vs Alignment 102 distance: -0.0
# Alignment 1 vs Alignment 103 distance: -0.0
# Alignment 1 vs Alignment 104 distance: -0.0
# Alignment 1 vs Alignment 105 distance: -0.0
# Alignment 1 vs Alignment 106 distance: -0.0
# Alignment 1 vs Alignment 107 distance: -0.0
# Alignment 1 vs Alignment 108 distance: -0.0
# Alignment 1 vs Alignment 109 distance: -0.0
# Alignment 1 vs Alignment 110 distance: -0.0
# Alignment 1 vs Alignment 111 distance: -0.0
# Alignment 1 vs Alignment 112 distance: -0.0
# Alignment 1 vs Alignment 113 distance: -0.0
# Alignment 1 vs Alignment 114 distance: -0.0
# Alignment 1 vs Alignment 115 distance: -0.0
# Alignment 1 vs Alignment 116 distance: -0.0
# Alignment 1 vs Alignment 117 distance: -0.0
# Alignment 1 vs Alignment 118 distance: -0.0
# Alignment 1 vs Alignment 119 distance: -0.0
# Alignment 1 vs Alignment 120 distance: -0.0
# Alignment 1 vs Alignment 121 distance: -0.0
# Alignment 1 vs Alignment 122 distance: -0.0
# Alignment 1 vs Alignment 123 distance: -0.0
# Alignment 1 vs Alignment 124 distance: -0.0
# Alignment 1 vs Alignment 125 distance: -0.0
# Alignment 1 vs Alignment 126 distance: -0.0
# Alignment 1 vs Alignment 127 distance: -0.0
# Alignment 1 vs Alignment 128 distance: -0.0
# Alignment 1 vs Alignment 129 distance: -0.0
# Alignment 1 vs Alignment 130 distance: -0.0
# Alignment 1 vs Alignment 131 distance: -0.0
# Alignment 1 vs Alignment 132 distance: -0.0
# Alignment 1 vs Alignment 133 distance: -0.0
# Alignment 1 vs Alignment 134 distance: -0.0
# Alignment 1 vs Alignment 135 distance: -0.0
# Alignment 1 vs Alignment 136 distance: -0.0
# Alignment 1 vs Alignment 137 distance: -0.0
# Alignment 1 vs Alignment 138 distance: -0.0
# Alignment 1 vs Alignment 139 distance: -0.0
# Alignment 1 vs Alignment 140 distance: -0.0
# Alignment 1 vs Alignment 141 distance: -0.0
# Alignment 1 vs Alignment 142 distance: -0.0
# Alignment 1 vs Alignment 143 distance: -0.0
# Alignment 1 vs Alignment 144 distance: -0.0
# Alignment 1 vs Alignment 145 distance: -0.0
# Alignment 1 vs Alignment 146 distance: -0.0
# Alignment 1 vs Alignment 147 distance: -0.0
# Alignment 1 vs Alignment 148 distance: -0.0
# Alignment 1 vs Alignment 149 distance: -0.0
# Alignment 1 vs Alignment 150 distance: -0.0
# Alignment 1 vs Alignment 151 distance: -0.0
# Alignment 1 vs Alignment 152 distance: -0.0
# Alignment 1 vs Alignment 153 distance: -0.0
# Alignment 1 vs Alignment 154 distance: -0.0
# Alignment 1 vs Alignment 155 distance: -0.0
# Alignment 1 vs Alignment 156 distance: -0.0
# Alignment 1 vs Alignment 157 distance: -0.0
# Alignment 1 vs Alignment 158 distance: -0.0
# Alignment 1 vs Alignment 159 distance: -0.0
# Alignment 1 vs Alignment 160 distance: -0.0
# Alignment 1 vs Alignment 161 distance: -0.0
# Alignment 1 vs Alignment 162 distance: -0.0
# Alignment 1 vs Alignment 163 distance: -0.0
# Alignment 1 vs Alignment 164 distance: -0.0
# Alignment 1 vs Alignment 165 distance: -0.0
# Alignment 1 vs Alignment 166 distance: -0.0
# Alignment 1 vs Alignment 167 distance: -0.0
# Alignment 1 vs Alignment 168 distance: -0.0
# Alignment 1 vs Alignment 169 distance: -0.0
# Alignment 1 vs Alignment 170 distance: -0.0
# Alignment 1 vs Alignment 171 distance: -0.0
# Alignment 1 vs Alignment 172 distance: -0.0
# Alignment 1 vs Alignment 173 distance: -0.0
# Alignment 1 vs Alignment 174 distance: -0.0
# Alignment 1 vs Alignment 175 distance: -0.0
# Alignment 1 vs Alignment 176 distance: -0.0
# Alignment 1 vs Alignment 177 distance: -0.0
# Alignment 1 vs Alignment 178 distance: -0.0
# Alignment 1 vs Alignment 179 distance: -0.0
# Alignment 1 vs Alignment 180 distance: -0.0
# Alignment 1 vs Alignment 181 distance: -0.0
# Alignment 1 vs Alignment 182 distance: -0.0
# Alignment 1 vs Alignment 183 distance: -0.0
# Alignment 1 vs Alignment 184 distance: -0.0
# Alignment 1 vs Alignment 185 distance: -0.0
# Alignment 1 vs Alignment 186 distance: -0.0
# Alignment 1 vs Alignment 187 distance: -0.0
# Alignment 1 vs Alignment 188 distance: -0.0
# Alignment 1 vs Alignment 189 distance: -0.0
# Alignment 1 vs Alignment 190 distance: -0.0
# Alignment 1 vs Alignment 191 distance: -0.0
# Alignment 1 vs Alignment 192 distance: -0.0
# Alignment 1 vs Alignment 193 distance: -0.0
# Alignment 1 vs Alignment 194 distance: -0.0
# Alignment 1 vs Alignment 195 distance: -0.0
# Alignment 1 vs Alignment 196 distance: -0.0
# Alignment 1 vs Alignment 197 distance: -0.0
# Alignment 1 vs Alignment 198 distance: -0.0
# Alignment 1 vs Alignment 199 distance: -0.0
# Alignment 1 vs Alignment 200 distance: -0.0
# Alignment 1 vs Alignment 201 distance: -0.0
# Alignment 1 vs Alignment 202 distance: -0.0
# Alignment 1 vs Alignment 203 distance: -0.0
# Alignment 1 vs Alignment 204 distance: -0.0
# Alignment 1 vs Alignment 205 distance: -0.0
# Alignment 1 vs Alignment 206 distance: -0.0
# Alignment 1 vs Alignment 207 distance: -0.0
# Alignment 1 vs Alignment 208 distance: -0.0
# Alignment 1 vs Alignment 209 distance: -0.0
# Alignment 1 vs Alignment 210 distance: -0.0
# Alignment 1 vs Alignment 211 distance: -0.0
# Alignment 1 vs Alignment 212 distance: -0.0
# Alignment 1 vs Alignment 213 distance: -0.0
# Alignment 1 vs Alignment 214 distance: -0.0
# Alignment 1 vs Alignment 215 distance: -0.0
# Alignment 1 vs Alignment 216 distance: -0.0
# Alignment 1 vs Alignment 217 distance: -0.0
# Alignment 1 vs Alignment 218 distance: -0.0
# Alignment 1 vs Alignment 219 distance: -0.0
# Alignment 1 vs Alignment 220 distance: -0.0
# Alignment 1 vs Alignment 221 distance: -0.0
# Alignment 1 vs Alignment 222 distance: -0.0
# Alignment 1 vs Alignment 223 distance: -0.0
# Alignment 1 vs Alignment 224 distance: -0.0
# Alignment 1 vs Alignment 225 distance: -0.0
# Alignment 1 vs Alignment 226 distance: -0.0
# Alignment 1 vs Alignment 227 distance: -0.0
# Alignment 1 vs Alignment 228 distance: -0.0
# Alignment 1 vs Alignment 229 distance: -0.0
# Alignment 1 vs Alignment 230 distance: -0.0
# Alignment 1 vs Alignment 231 distance: -0.0
# Alignment 1 vs Alignment 232 distance: -0.0
# Alignment 1 vs Alignment 233 distance: -0.0
# Alignment 1 vs Alignment 234 distance: -0.0
# Alignment 1 vs Alignment 235 distance: -0.0
# Alignment 1 vs Alignment 236 distance: -0.0
# Alignment 1 vs Alignment 237 distance: -0.0
# Alignment 1 vs Alignment 238 distance: -0.0
# Alignment 1 vs Alignment 239 distance: -0.0
# Alignment 1 vs Alignment 240 distance: -0.0
# Alignment 1 vs Alignment 241 distance: -0.0
# Alignment 1 vs Alignment 242 distance: -0.0
# Alignment 1 vs Alignment 243 distance: -0.0
# Alignment 1 vs Alignment 244 distance: -0.0
# Alignment 1 vs Alignment 245 distance: -0.0
# Alignment 1 vs Alignment 246 distance: -0.0
# Alignment 1 vs Alignment 247 distance: -0.0
# Alignment 1 vs Alignment 248 distance: -0.0
# Alignment 1 vs Alignment 249 distance: -0.0
# Alignment 1 vs Alignment 250 distance: -0.0
# Alignment 1 vs Alignment 251 distance: -0.0
# Alignment 1 vs Alignment 252 distance: -0.0
# Alignment 1 vs Alignment 253 distance: -0.0
# Alignment 1 vs Alignment 254 distance: -0.0
# Alignment 1 vs Alignment 255 distance: -0.0
# Alignment 1 vs Alignment 256 distance: -0.0
# Alignment 1 vs Alignment 257 distance: -0.0
# Alignment 1 vs Alignment 258 distance: -0.0
# Alignment 1 vs Alignment 259 distance: -0.0
# Alignment 1 vs Alignment 260 distance: -0.0
# Alignment 1 vs Alignment 261 distance: -0.0
# Alignment 1 vs Alignment 262 distance: -0.0
# Alignment 1 vs Alignment 263 distance: -0.0
# Alignment 1 vs Alignment 264 distance: -0.0
# Alignment 1 vs Alignment 265 distance: -0.0
# Alignment 1 vs Alignment 266 distance: -0.0
# Alignment 1 vs Alignment 267 distance: -0.0
# Alignment 1 vs Alignment 268 distance: -0.0
# Alignment 1 vs Alignment 269 distance: -0.0
# Alignment 1 vs Alignment 270 distance: -0.0
# Alignment 1 vs Alignment 271 distance: -0.0
# Alignment 1 vs Alignment 272 distance: -0.0
# Alignment 1 vs Alignment 273 distance: -0.0
# Alignment 1 vs Alignment 274 distance: -0.0
# Alignment 1 vs Alignment 275 distance: -0.0
# Alignment 1 vs Alignment 276 distance: -0.0
# Alignment 1 vs Alignment 277 distance: -0.0
# Alignment 1 vs Alignment 278 distance: -0.0
# Alignment 1 vs Alignment 279 distance: -0.0
# Alignment 1 vs Alignment 280 distance: -0.0
# Alignment 1 vs Alignment 281 distance: -0.0
# Alignment 1 vs Alignment 282 distance: -0.0
# Alignment 1 vs Alignment 283 distance: -0.0
# Alignment 1 vs Alignment 284 distance: -0.0
# Alignment 1 vs Alignment 285 distance: -0.0
# Alignment 1 vs Alignment 286 distance: -0.0
# Alignment 1 vs Alignment 287 distance: -0.0
# Alignment 1 vs Alignment 288 distance: -0.0
# Alignment 1 vs Alignment 289 distance: -0.0
# Alignment 1 vs Alignment 290 distance: -0.0
# Alignment 1 vs Alignment 291 distance: -0.0
# Alignment 1 vs Alignment 292 distance: -0.0
# Alignment 1 vs Alignment 293 distance: -0.0
# Alignment 1 vs Alignment 294 distance: -0.0
# Alignment 1 vs Alignment 295 distance: -0.0
# Alignment 1 vs Alignment 296 distance: -0.0
# Alignment 1 vs Alignment 297 distance: -0.0
# Alignment 1 vs Alignment 298 distance: -0.0
# Alignment 1 vs Alignment 299 distance: -0.0
# Alignment 1 vs Alignment 300 distance: -0.0
# Alignment 1 vs Alignment 301 distance: -0.0
# Alignment 1 vs Alignment 302 distance: -0.0
# Alignment 1 vs Alignment 303 distance: -0.0
# Alignment 1 vs Alignment 304 distance: -0.0
# Alignment 1 vs Alignment 305 distance: -0.0
# Alignment 1 vs Alignment 306 distance: -0.0
# Alignment 1 vs Alignment 307 distance: -0.0
# Alignment 1 vs Alignment 308 distance: -0.0
# Alignment 1 vs Alignment 309 distance: -0.0
# Alignment 1 vs Alignment 310 distance: -0.0
# Alignment 1 vs Alignment 311 distance: -0.0
# Alignment 1 vs Alignment 312 distance: -0.0
# Alignment 1 vs Alignment 313 distance: -0.0
# Alignment 1 vs Alignment 314 distance: -0.0
# Alignment 1 vs Alignment 315 distance: -0.0
# Alignment 1 vs Alignment 316 distance: -0.0
# Alignment 1 vs Alignment 317 distance: -0.0
# Alignment 1 vs Alignment 318 distance: -0.0
# Alignment 1 vs Alignment 319 distance: -0.0
# Alignment 1 vs Alignment 320 distance: -0.0
# Alignment 1 vs Alignment 321 distance: -0.0
# Alignment 1 vs Alignment 322 distance: -0.0
# Alignment 1 vs Alignment 323 distance: -0.0
# Alignment 1 vs Alignment 324 distance: -0.0
# Alignment 1 vs Alignment 325 distance: -0.0
# Alignment 1 vs Alignment 326 distance: -0.0
# Alignment 1 vs Alignment 327 distance: -0.0
# Alignment 1 vs Alignment 328 distance: -0.0
# Alignment 1 vs Alignment 329 distance: -0.0
# Alignment 1 vs Alignment 330 distance: -0.0
# Alignment 1 vs Alignment 331 distance: -0.0
# Alignment 1 vs Alignment 332 distance: -0.0
# Alignment 1 vs Alignment 333 distance: -0.0
# Alignment 1 vs Alignment 334 distance: -0.0
# Alignment 1 vs Alignment 335 distance: -0.0
# Alignment 1 vs Alignment 336 distance: -0.0
# Alignment 1 vs Alignment 337 distance: -0.0
# Alignment 1 vs Alignment 338 distance: -0.0
# Alignment 1 vs Alignment 339 distance: -0.0
# Alignment 1 vs Alignment 340 distance: -0.0
# Alignment 1 vs Alignment 341 distance: -0.0
# Alignment 1 vs Alignment 342 distance: -0.0
# Alignment 1 vs Alignment 343 distance: -0.0
# Alignment 1 vs Alignment 344 distance: -0.0
# Alignment 1 vs Alignment 345 distance: -0.0
# Alignment 1 vs Alignment 346 distance: -0.0
# Alignment 1 vs Alignment 347 distance: -0.0
# Alignment 1 vs Alignment 348 distance: -0.0
# Alignment 1 vs Alignment 349 distance: -0.0
# Alignment 1 vs Alignment 350 distance: -0.0
# Alignment 1 vs Alignment 351 distance: -0.0
# Alignment 1 vs Alignment 352 distance: -0.0
# Alignment 1 vs Alignment 353 distance: -0.0
# Alignment 1 vs Alignment 354 distance: -0.0
# Alignment 1 vs Alignment 355 distance: -0.0
# Alignment 1 vs Alignment 356 distance: -0.0
# Alignment 1 vs Alignment 357 distance: -0.0
# Alignment 1 vs Alignment 358 distance: -0.0
# Alignment 1 vs Alignment 359 distance: -0.0
# Alignment 1 vs Alignment 360 distance: -0.0
# Alignment 1 vs Alignment 361 distance: nan
# Alignment 1 vs Alignment 362 distance: nan
# Alignment 1 vs Alignment 363 distance: nan
# Alignment 1 vs Alignment 364 distance: nan
# Alignment 1 vs Alignment 365 distance: nan
# Alignment 1 vs Alignment 366 distance: nan
# Alignment 1 vs Alignment 367 distance: nan
# Alignment 1 vs Alignment 368 distance: nan
# Alignment 1 vs Alignment 369 distance: nan
# Alignment 1 vs Alignment 370 distance: nan
# Alignment 1 vs Alignment 371 distance: nan
# Alignment 1 vs Alignment 372 distance: nan
# Alignment 1 vs Alignment 373 distance: nan
# Alignment 1 vs Alignment 374 distance: nan
# Alignment 1 vs Alignment 375 distance: nan
# Alignment 1 vs Alignment 376 distance: nan
# Alignment 1 vs Alignment 377 distance: nan
# Alignment 1 vs Alignment 378 distance: nan
# Alignment 1 vs Alignment 379 distance: nan
# Alignment 1 vs Alignment 380 distance: nan
# Alignment 1 vs Alignment 381 distance: nan
# Alignment 1 vs Alignment 382 distance: nan
# Alignment 1 vs Alignment 383 distance: nan
# Alignment 1 vs Alignment 384 distance: nan
# Alignment 1 vs Alignment 385 distance: nan
# Alignment 1 vs Alignment 386 distance: nan
# Alignment 1 vs Alignment 387 distance: nan
# Alignment 1 vs Alignment 388 distance: nan
# Alignment 1 vs Alignment 389 distance: nan
# Alignment 1 vs Alignment 390 distance: nan
# Alignment 1 vs Alignment 391 distance: nan
# Alignment 1 vs Alignment 392 distance: nan
# Alignment 1 vs Alignment 393 distance: nan
# Alignment 1 vs Alignment 394 distance: nan
# Alignment 1 vs Alignment 395 distance: nan
# Alignment 1 vs Alignment 396 distance: nan
# Alignment 1 vs Alignment 397 distance: nan
# Alignment 1 vs Alignment 398 distance: nan
# Alignment 1 vs Alignment 399 distance: nan
# Alignment 1 vs Alignment 400 distance: nan
# Alignment 1 vs Alignment 401 distance: nan
# Alignment 1 vs Alignment 402 distance: nan
# Alignment 1 vs Alignment 403 distance: nan
# Alignment 1 vs Alignment 404 distance: nan
# Alignment 1 vs Alignment 405 distance: nan
# Alignment 1 vs Alignment 406 distance: nan
# Alignment 1 vs Alignment 407 distance: nan
# Alignment 1 vs Alignment 408 distance: nan
# Alignment 1 vs Alignment 409 distance: nan
# Alignment 1 vs Alignment 410 distance: nan
# Alignment 1 vs Alignment 411 distance: nan
# Alignment 1 vs Alignment 412 distance: nan
# Alignment 1 vs Alignment 413 distance: nan
# Alignment 1 vs Alignment 414 distance: nan
# Alignment 1 vs Alignment 415 distance: nan
# Alignment 1 vs Alignment 416 distance: nan
# Alignment 1 vs Alignment 417 distance: nan
# Alignment 1 vs Alignment 418 distance: nan
# Alignment 1 vs Alignment 419 distance: nan
# Alignment 1 vs Alignment 420 distance: nan
# Alignment 1 vs Alignment 421 distance: nan
# Alignment 1 vs Alignment 422 distance: nan
# Alignment 1 vs Alignment 423 distance: nan
# Alignment 1 vs Alignment 424 distance: nan
# Alignment 1 vs Alignment 425 distance: nan
# Alignment 1 vs Alignment 426 distance: nan
# Alignment 1 vs Alignment 427 distance: nan
# Alignment 1 vs Alignment 428 distance: nan
# Alignment 1 vs Alignment 429 distance: nan
# Alignment 1 vs Alignment 430 distance: nan
# Alignment 1 vs Alignment 431 distance: nan
# Alignment 1 vs Alignment 432 distance: nan
# Alignment 1 vs Alignment 433 distance: nan
# Alignment 1 vs Alignment 434 distance: nan
# Alignment 1 vs Alignment 435 distance: nan
# Alignment 1 vs Alignment 436 distance: nan
# Alignment 1 vs Alignment 437 distance: nan
# Alignment 1 vs Alignment 438 distance: nan
# Alignment 1 vs Alignment 439 distance: nan
# Alignment 1 vs Alignment 440 distance: nan
# Alignment 1 vs Alignment 441 distance: nan
# Alignment 1 vs Alignment 442 distance: nan
# Alignment 1 vs Alignment 443 distance: nan
# Alignment 1 vs Alignment 444 distance: nan
# Alignment 1 vs Alignment 445 distance: nan
# Alignment 1 vs Alignment 446 distance: nan
# Alignment 1 vs Alignment 447 distance: nan
# Alignment 1 vs Alignment 448 distance: nan
# Alignment 1 vs Alignment 449 distance: nan
# Alignment 1 vs Alignment 450 distance: nan
# Alignment 1 vs Alignment 451 distance: nan
# Alignment 1 vs Alignment 452 distance: nan
# Alignment 1 vs Alignment 453 distance: nan
# Alignment 1 vs Alignment 454 distance: nan
# Alignment 1 vs Alignment 455 distance: nan
# Alignment 1 vs Alignment 456 distance: nan
# Alignment 1 vs Alignment 457 distance: nan
# Alignment 1 vs Alignment 458 distance: nan
# Alignment 1 vs Alignment 459 distance: nan
# Alignment 1 vs Alignment 460 distance: nan
# Alignment 1 vs Alignment 461 distance: nan
# Alignment 1 vs Alignment 462 distance: nan
# Alignment 1 vs Alignment 463 distance: nan
# Alignment 1 vs Alignment 464 distance: nan
# Alignment 1 vs Alignment 465 distance: nan
# Alignment 1 vs Alignment 466 distance: nan
# Alignment 1 vs Alignment 467 distance: nan
# Alignment 1 vs Alignment 468 distance: nan
# Alignment 1 vs Alignment 469 distance: nan
# Alignment 1 vs Alignment 470 distance: nan
# Alignment 1 vs Alignment 471 distance: nan
# Alignment 1 vs Alignment 472 distance: nan
# Alignment 1 vs Alignment 473 distance: nan
# Alignment 1 vs Alignment 474 distance: nan
# Alignment 1 vs Alignment 475 distance: nan
# Alignment 1 vs Alignment 476 distance: nan
# Alignment 1 vs Alignment 477 distance: nan
# Alignment 1 vs Alignment 478 distance: nan
# Alignment 1 vs Alignment 479 distance: nan
# Alignment 1 vs Alignment 480 distance: nan
# Alignment 1 vs Alignment 481 distance: nan
# Alignment 1 vs Alignment 482 distance: nan
# Alignment 1 vs Alignment 483 distance: nan
# Alignment 1 vs Alignment 484 distance: nan
# Alignment 1 vs Alignment 485 distance: nan
# Alignment 1 vs Alignment 486 distance: nan
# Alignment 1 vs Alignment 487 distance: nan
# Alignment 1 vs Alignment 488 distance: nan
# Alignment 1 vs Alignment 489 distance: nan
# Alignment 1 vs Alignment 490 distance: nan
# Alignment 1 vs Alignment 491 distance: nan
# Alignment 1 vs Alignment 492 distance: nan
# Alignment 1 vs Alignment 493 distance: nan
# Alignment 1 vs Alignment 494 distance: nan
# Alignment 1 vs Alignment 495 distance: nan
# Alignment 1 vs Alignment 496 distance: nan
# Alignment 1 vs Alignment 497 distance: nan
# Alignment 1 vs Alignment 498 distance: nan
# Alignment 1 vs Alignment 499 distance: nan
# Alignment 1 vs Alignment 500 distance: nan
# Alignment 1 vs Alignment 501 distance: nan
# Alignment 1 vs Alignment 502 distance: nan
# Alignment 1 vs Alignment 503 distance: nan
# Alignment 1 vs Alignment 504 distance: nan
# Alignment 1 vs Alignment 505 distance: nan
# Alignment 1 vs Alignment 506 distance: nan
# Alignment 1 vs Alignment 507 distance: nan
# Alignment 1 vs Alignment 508 distance: nan
# Alignment 1 vs Alignment 509 distance: nan
# Alignment 1 vs Alignment 510 distance: nan
# Alignment 1 vs Alignment 511 distance: nan
# Alignment 1 vs Alignment 512 distance: nan
# Alignment 1 vs Alignment 513 distance: nan
# Alignment 1 vs Alignment 514 distance: nan
# Alignment 1 vs Alignment 515 distance: nan
# Alignment 1 vs Alignment 516 distance: nan
# Alignment 1 vs Alignment 517 distance: nan
# Alignment 1 vs Alignment 518 distance: nan
# Alignment 1 vs Alignment 519 distance: nan
# Alignment 1 vs Alignment 520 distance: nan
# Alignment 1 vs Alignment 521 distance: nan
# Alignment 1 vs Alignment 522 distance: nan
# Alignment 1 vs Alignment 523 distance: nan
# Alignment 1 vs Alignment 524 distance: nan
# Alignment 1 vs Alignment 525 distance: nan
# Alignment 1 vs Alignment 526 distance: nan
# Alignment 1 vs Alignment 527 distance: nan
# Alignment 1 vs Alignment 528 distance: nan
# Alignment 1 vs Alignment 529 distance: nan
# Alignment 1 vs Alignment 530 distance: nan
# Alignment 1 vs Alignment 531 distance: nan
# Alignment 1 vs Alignment 532 distance: nan
# Alignment 1 vs Alignment 533 distance: nan
# Alignment 1 vs Alignment 534 distance: nan
# Alignment 1 vs Alignment 535 distance: nan
# Alignment 1 vs Alignment 536 distance: nan
# Alignment 1 vs Alignment 537 distance: nan
# Alignment 1 vs Alignment 538 distance: nan
# Alignment 1 vs Alignment 539 distance: nan
# Alignment 1 vs Alignment 540 distance: nan
# Alignment 1 vs Alignment 541 distance: nan
# Alignment 1 vs Alignment 542 distance: nan
# Alignment 1 vs Alignment 543 distance: nan
# Alignment 1 vs Alignment 544 distance: nan
# Alignment 1 vs Alignment 545 distance: nan
# Alignment 1 vs Alignment 546 distance: nan
# Alignment 1 vs Alignment 547 distance: nan
# Alignment 1 vs Alignment 548 distance: nan
# Alignment 1 vs Alignment 549 distance: nan
# Alignment 1 vs Alignment 550 distance: nan
# Alignment 1 vs Alignment 551 distance: nan
# Alignment 1 vs Alignment 552 distance: nan
# Alignment 1 vs Alignment 553 distance: nan
# Alignment 1 vs Alignment 554 distance: nan
# Alignment 1 vs Alignment 555 distance: nan
# Alignment 1 vs Alignment 556 distance: nan
# Alignment 1 vs Alignment 557 distance: nan
# Alignment 1 vs Alignment 558 distance: nan
# Alignment 1 vs Alignment 559 distance: nan
# Alignment 1 vs Alignment 560 distance: nan
# Alignment 1 vs Alignment 561 distance: nan
# Alignment 1 vs Alignment 562 distance: nan
# Alignment 1 vs Alignment 563 distance: nan
# Alignment 1 vs Alignment 564 distance: nan
# Alignment 1 vs Alignment 565 distance: nan
# Alignment 1 vs Alignment 566 distance: nan
# Alignment 1 vs Alignment 567 distance: nan
# Alignment 1 vs Alignment 568 distance: nan
# Alignment 1 vs Alignment 569 distance: nan
# Alignment 1 vs Alignment 570 distance: nan
# Alignment 1 vs Alignment 571 distance: nan
# Alignment 1 vs Alignment 572 distance: nan
# Alignment 1 vs Alignment 573 distance: nan
# Alignment 1 vs Alignment 574 distance: nan
# Alignment 1 vs Alignment 575 distance: nan
# Alignment 1 vs Alignment 576 distance: nan
# Alignment 1 vs Alignment 577 distance: nan
# Alignment 1 vs Alignment 578 distance: nan
# Alignment 1 vs Alignment 579 distance: nan
# Alignment 1 vs Alignment 580 distance: nan
# Alignment 1 vs Alignment 581 distance: nan
# Alignment 1 vs Alignment 582 distance: nan
# Alignment 1 vs Alignment 583 distance: nan
# Alignment 1 vs Alignment 584 distance: nan
# Alignment 1 vs Alignment 585 distance: nan
# Alignment 1 vs Alignment 586 distance: nan
# Alignment 1 vs Alignment 587 distance: nan
# Alignment 1 vs Alignment 588 distance: nan
# Alignment 1 vs Alignment 589 distance: nan
# Alignment 1 vs Alignment 590 distance: nan
# Alignment 1 vs Alignment 591 distance: nan
# Alignment 1 vs Alignment 592 distance: nan
# Alignment 1 vs Alignment 593 distance: nan
# Alignment 1 vs Alignment 594 distance: nan
# Alignment 1 vs Alignment 595 distance: nan
# Alignment 1 vs Alignment 596 distance: nan
# Alignment 1 vs Alignment 597 distance: nan
# Alignment 1 vs Alignment 598 distance: nan
# Alignment 1 vs Alignment 599 distance: nan
# Alignment 1 vs Alignment 600 distance: nan
# Alignment 1 vs Alignment 601 distance: nan
# Alignment 1 vs Alignment 602 distance: nan
# Alignment 1 vs Alignment 603 distance: nan
# Alignment 1 vs Alignment 604 distance: nan
# Alignment 1 vs Alignment 605 distance: nan
# Alignment 1 vs Alignment 606 distance: nan
# Alignment 1 vs Alignment 607 distance: nan
# Alignment 1 vs Alignment 608 distance: nan
# Alignment 1 vs Alignment 609 distance: nan
# Alignment 1 vs Alignment 610 distance: nan
# Alignment 1 vs Alignment 611 distance: nan
# Alignment 1 vs Alignment 612 distance: nan
# Alignment 1 vs Alignment 613 distance: nan
# Alignment 1 vs Alignment 614 distance: nan
# Alignment 1 vs Alignment 615 distance: nan
# Alignment 1 vs Alignment 616 distance: nan
# Alignment 1 vs Alignment 617 distance: nan
# Alignment 1 vs Alignment 618 distance: nan
# Alignment 1 vs Alignment 619 distance: nan
# Alignment 1 vs Alignment 620 distance: nan
# Alignment 1 vs Alignment 621 distance: nan
# Alignment 1 vs Alignment 622 distance: nan
# Alignment 1 vs Alignment 623 distance: nan
# Alignment 1 vs Alignment 624 distance: nan
# Alignment 1 vs Alignment 625 distance: nan
# Alignment 1 vs Alignment 626 distance: nan
# Alignment 1 vs Alignment 627 distance: nan
# Alignment 1 vs Alignment 628 distance: nan
# Alignment 1 vs Alignment 629 distance: nan
# Alignment 1 vs Alignment 630 distance: nan
# Alignment 1 vs Alignment 631 distance: nan
# Alignment 1 vs Alignment 632 distance: nan
# Alignment 1 vs Alignment 633 distance: nan
# Alignment 1 vs Alignment 634 distance: nan
# Alignment 1 vs Alignment 635 distance: nan
# Alignment 1 vs Alignment 636 distance: nan
# Alignment 1 vs Alignment 637 distance: nan
# Alignment 1 vs Alignment 638 distance: nan
# Alignment 1 vs Alignment 639 distance: nan
# Alignment 1 vs Alignment 640 distance: nan
# Alignment 1 vs Alignment 641 distance: nan
# Alignment 1 vs Alignment 642 distance: nan
# Alignment 1 vs Alignment 643 distance: nan
# Alignment 1 vs Alignment 644 distance: nan
# Alignment 1 vs Alignment 645 distance: nan
# Alignment 1 vs Alignment 646 distance: nan
# Alignment 1 vs Alignment 647 distance: nan
# Alignment 1 vs Alignment 648 distance: nan
# Alignment 1 vs Alignment 649 distance: nan
# Alignment 1 vs Alignment 650 distance: nan
# Alignment 1 vs Alignment 651 distance: nan
# Alignment 1 vs Alignment 652 distance: nan
# Alignment 1 vs Alignment 653 distance: nan
# Alignment 1 vs Alignment 654 distance: nan
# Alignment 1 vs Alignment 655 distance: nan
# Alignment 1 vs Alignment 656 distance: nan
# Alignment 1 vs Alignment 657 distance: nan
# Alignment 1 vs Alignment 658 distance: nan
# Alignment 1 vs Alignment 659 distance: nan
# Alignment 1 vs Alignment 660 distance: nan
# Alignment 1 vs Alignment 661 distance: nan
# Alignment 1 vs Alignment 662 distance: nan
# Alignment 1 vs Alignment 663 distance: nan
# Alignment 1 vs Alignment 664 distance: nan
# Alignment 1 vs Alignment 665 distance: nan
# Alignment 1 vs Alignment 666 distance: nan
# Alignment 1 vs Alignment 667 distance: nan
# Alignment 1 vs Alignment 668 distance: nan
# Alignment 1 vs Alignment 669 distance: nan
# Alignment 1 vs Alignment 670 distance: nan
# Alignment 1 vs Alignment 671 distance: nan
# Alignment 1 vs Alignment 672 distance: nan
# Alignment 1 vs Alignment 673 distance: nan
# Alignment 1 vs Alignment 674 distance: nan
# Alignment 1 vs Alignment 675 distance: nan
# Alignment 1 vs Alignment 676 distance: nan
# Alignment 1 vs Alignment 677 distance: nan
# Alignment 1 vs Alignment 678 distance: nan
# Alignment 1 vs Alignment 679 distance: nan
# Alignment 1 vs Alignment 680 distance: nan
# Alignment 1 vs Alignment 681 distance: nan
# Alignment 1 vs Alignment 682 distance: nan
# Alignment 1 vs Alignment 683 distance: nan
# Alignment 1 vs Alignment 684 distance: nan
# Alignment 1 vs Alignment 685 distance: nan
# Alignment 1 vs Alignment 686 distance: nan
# Alignment 1 vs Alignment 687 distance: nan
# Alignment 1 vs Alignment 688 distance: nan
# Alignment 1 vs Alignment 689 distance: nan
# Alignment 1 vs Alignment 690 distance: nan
# Alignment 1 vs Alignment 691 distance: nan
# Alignment 1 vs Alignment 692 distance: nan
# Alignment 1 vs Alignment 693 distance: nan
# Alignment 1 vs Alignment 694 distance: nan
# Alignment 1 vs Alignment 695 distance: nan
# Alignment 1 vs Alignment 696 distance: nan
# Alignment 1 vs Alignment 697 distance: nan
# Alignment 1 vs Alignment 698 distance: nan
# Alignment 1 vs Alignment 699 distance: nan
# Alignment 1 vs Alignment 700 distance: nan
# Alignment 1 vs Alignment 701 distance: nan
# Alignment 1 vs Alignment 702 distance: nan
# Alignment 1 vs Alignment 703 distance: nan
# Alignment 1 vs Alignment 704 distance: nan
# Alignment 1 vs Alignment 705 distance: nan
# Alignment 1 vs Alignment 706 distance: nan
# Alignment 1 vs Alignment 707 distance: nan
# Alignment 1 vs Alignment 708 distance: nan
# Alignment 1 vs Alignment 709 distance: nan
# Alignment 1 vs Alignment 710 distance: nan
# Alignment 1 vs Alignment 711 distance: nan
# Alignment 1 vs Alignment 712 distance: nan
# Alignment 1 vs Alignment 713 distance: nan
# Alignment 1 vs Alignment 714 distance: nan
# Alignment 1 vs Alignment 715 distance: nan
# Alignment 1 vs Alignment 716 distance: nan
# Alignment 1 vs Alignment 717 distance: nan
# Alignment 1 vs Alignment 718 distance: nan
# Alignment 1 vs Alignment 719 distance: nan
# Alignment 1 vs Alignment 720 distance: nan
# Alignment 1 vs Alignment 721 distance: nan
# Alignment 1 vs Alignment 722 distance: nan
# Alignment 1 vs Alignment 723 distance: nan
# Alignment 1 vs Alignment 724 distance: nan
# Alignment 1 vs Alignment 725 distance: nan
# Alignment 1 vs Alignment 726 distance: nan
# Alignment 1 vs Alignment 727 distance: nan
# Alignment 1 vs Alignment 728 distance: nan
# Alignment 1 vs Alignment 729 distance: nan
# Alignment 1 vs Alignment 730 distance: nan
# Alignment 1 vs Alignment 731 distance: nan
# Alignment 1 vs Alignment 732 distance: nan
# Alignment 1 vs Alignment 733 distance: nan
# Alignment 1 vs Alignment 734 distance: nan
# Alignment 1 vs Alignment 735 distance: nan
# Alignment 1 vs Alignment 736 distance: nan
# Alignment 1 vs Alignment 737 distance: nan
# Alignment 1 vs Alignment 738 distance: nan
# Alignment 1 vs Alignment 739 distance: nan
# Alignment 1 vs Alignment 740 distance: nan
# Alignment 1 vs Alignment 741 distance: nan
# Alignment 1 vs Alignment 742 distance: nan
# Alignment 1 vs Alignment 743 distance: nan
# Alignment 1 vs Alignment 744 distance: nan
# Alignment 1 vs Alignment 745 distance: nan
# Alignment 1 vs Alignment 746 distance: nan
# Alignment 1 vs Alignment 747 distance: nan
# Alignment 1 vs Alignment 748 distance: nan
# Alignment 1 vs Alignment 749 distance: nan
# Alignment 1 vs Alignment 750 distance: nan
# Alignment 1 vs Alignment 751 distance: nan
# Alignment 1 vs Alignment 752 distance: nan
# Alignment 1 vs Alignment 753 distance: nan
# Alignment 1 vs Alignment 754 distance: nan
# Alignment 1 vs Alignment 755 distance: nan
# Alignment 1 vs Alignment 756 distance: nan
# Alignment 1 vs Alignment 757 distance: nan
# Alignment 1 vs Alignment 758 distance: nan
# Alignment 1 vs Alignment 759 distance: nan
# Alignment 1 vs Alignment 760 distance: nan
# Alignment 1 vs Alignment 761 distance: nan
# Alignment 1 vs Alignment 762 distance: nan
# Alignment 1 vs Alignment 763 distance: nan
# Alignment 1 vs Alignment 764 distance: nan
# Alignment 1 vs Alignment 765 distance: nan
# Alignment 1 vs Alignment 766 distance: nan
# Alignment 1 vs Alignment 767 distance: nan
# Alignment 1 vs Alignment 768 distance: nan
# Alignment 1 vs Alignment 769 distance: nan
# Alignment 1 vs Alignment 770 distance: nan
# Alignment 1 vs Alignment 771 distance: nan
# Alignment 1 vs Alignment 772 distance: nan
# Alignment 1 vs Alignment 773 distance: nan
# Alignment 1 vs Alignment 774 distance: nan
# Alignment 1 vs Alignment 775 distance: nan
# Alignment 1 vs Alignment 776 distance: nan
# Alignment 1 vs Alignment 777 distance: nan
# Alignment 1 vs Alignment 778 distance: nan
# Alignment 1 vs Alignment 779 distance: nan
# Alignment 1 vs Alignment 780 distance: nan
# Alignment 1 vs Alignment 781 distance: nan
# Alignment 1 vs Alignment 782 distance: nan
# Alignment 1 vs Alignment 783 distance: nan
# Alignment 1 vs Alignment 784 distance: nan
# Alignment 1 vs Alignment 785 distance: nan
# Alignment 1 vs Alignment 786 distance: nan
# Alignment 1 vs Alignment 787 distance: nan
# Alignment 1 vs Alignment 788 distance: nan
# Alignment 1 vs Alignment 789 distance: nan
# Alignment 1 vs Alignment 790 distance: nan
# Alignment 1 vs Alignment 791 distance: nan
# Alignment 1 vs Alignment 792 distance: nan
# Alignment 1 vs Alignment 793 distance: nan
# Alignment 1 vs Alignment 794 distance: nan
# Alignment 1 vs Alignment 795 distance: nan
# Alignment 1 vs Alignment 796 distance: nan
# Alignment 1 vs Alignment 797 distance: nan
# Alignment 1 vs Alignment 798 distance: nan
# Alignment 1 vs Alignment 799 distance: nan
# Alignment 1 vs Alignment 800 distance: nan
# Alignment 1 vs Alignment 801 distance: nan
# Alignment 1 vs Alignment 802 distance: nan
# Alignment 1 vs Alignment 803 distance: nan
# Alignment 1 vs Alignment 804 distance: nan
# Alignment 1 vs Alignment 805 distance: nan
# Alignment 1 vs Alignment 806 distance: nan
# Alignment 1 vs Alignment 807 distance: nan
# Alignment 1 vs Alignment 808 distance: nan
# Alignment 1 vs Alignment 809 distance: nan
# Alignment 1 vs Alignment 810 distance: nan
# Alignment 1 vs Alignment 811 distance: nan
# Alignment 1 vs Alignment 812 distance: nan
# Alignment 1 vs Alignment 813 distance: nan
# Alignment 1 vs Alignment 814 distance: nan
# Alignment 1 vs Alignment 815 distance: nan
# Alignment 1 vs Alignment 816 distance: nan
# Alignment 1 vs Alignment 817 distance: nan
# Alignment 1 vs Alignment 818 distance: nan
# Alignment 1 vs Alignment 819 distance: nan
# Alignment 1 vs Alignment 820 distance: nan
# Alignment 1 vs Alignment 821 distance: nan
# Alignment 1 vs Alignment 822 distance: nan
# Alignment 1 vs Alignment 823 distance: nan
# Alignment 1 vs Alignment 824 distance: nan
# Alignment 1 vs Alignment 825 distance: nan
# Alignment 1 vs Alignment 826 distance: nan
# Alignment 1 vs Alignment 827 distance: nan
# Alignment 1 vs Alignment 828 distance: nan
# Alignment 1 vs Alignment 829 distance: nan
# Alignment 1 vs Alignment 830 distance: nan
# Alignment 1 vs Alignment 831 distance: nan
# Alignment 1 vs Alignment 832 distance: nan
# Alignment 1 vs Alignment 833 distance: nan
# Alignment 1 vs Alignment 834 distance: nan
# Alignment 1 vs Alignment 835 distance: nan
# Alignment 1 vs Alignment 836 distance: nan
# Alignment 1 vs Alignment 837 distance: nan
# Alignment 1 vs Alignment 838 distance: nan
# Alignment 1 vs Alignment 839 distance: nan
# Alignment 1 vs Alignment 840 distance: nan
# Alignment 1 vs Alignment 841 distance: nan
# Alignment 1 vs Alignment 842 distance: nan
# Alignment 1 vs Alignment 843 distance: nan
# Alignment 1 vs Alignment 844 distance: nan
# Alignment 1 vs Alignment 845 distance: nan
# Alignment 1 vs Alignment 846 distance: nan
# Alignment 1 vs Alignment 847 distance: nan
# Alignment 1 vs Alignment 848 distance: nan
# Alignment 1 vs Alignment 849 distance: nan
# Alignment 1 vs Alignment 850 distance: nan
# Alignment 1 vs Alignment 851 distance: nan
# Alignment 1 vs Alignment 852 distance: nan
# Alignment 1 vs Alignment 853 distance: nan
# Alignment 1 vs Alignment 854 distance: nan
# Alignment 1 vs Alignment 855 distance: nan
# Alignment 1 vs Alignment 856 distance: nan
# Alignment 1 vs Alignment 857 distance: nan
# Alignment 1 vs Alignment 858 distance: nan
# Alignment 1 vs Alignment 859 distance: nan
# Alignment 1 vs Alignment 860 distance: nan
# Alignment 1 vs Alignment 861 distance: nan
# Alignment 1 vs Alignment 862 distance: nan
# Alignment 1 vs Alignment 863 distance: nan
# Alignment 1 vs Alignment 864 distance: nan
# Alignment 1 vs Alignment 865 distance: nan
# Alignment 1 vs Alignment 866 distance: nan
# Alignment 1 vs Alignment 867 distance: nan
# Alignment 1 vs Alignment 868 distance: nan
# Alignment 1 vs Alignment 869 distance: nan
# Alignment 1 vs Alignment 870 distance: nan
# Alignment 1 vs Alignment 871 distance: nan
# Alignment 1 vs Alignment 872 distance: nan
# Alignment 1 vs Alignment 873 distance: nan
# Alignment 1 vs Alignment 874 distance: nan
# Alignment 1 vs Alignment 875 distance: nan
# Alignment 1 vs Alignment 876 distance: nan
# Alignment 1 vs Alignment 877 distance: nan
# Alignment 1 vs Alignment 878 distance: nan
# Alignment 1 vs Alignment 879 distance: nan
# Alignment 1 vs Alignment 880 distance: nan
# Alignment 1 vs Alignment 881 distance: nan
# Alignment 1 vs Alignment 882 distance: nan
# Alignment 1 vs Alignment 883 distance: nan
# Alignment 1 vs Alignment 884 distance: nan
# Alignment 1 vs Alignment 885 distance: nan
# Alignment 1 vs Alignment 886 distance: nan
# Alignment 1 vs Alignment 887 distance: nan
# Alignment 1 vs Alignment 888 distance: nan
# Alignment 1 vs Alignment 889 distance: nan
# Alignment 1 vs Alignment 890 distance: nan
# Alignment 1 vs Alignment 891 distance: nan
# Alignment 1 vs Alignment 892 distance: nan
# Alignment 1 vs Alignment 893 distance: nan
# Alignment 1 vs Alignment 894 distance: nan
# Alignment 1 vs Alignment 895 distance: nan
# Alignment 1 vs Alignment 896 distance: nan
# Alignment 1 vs Alignment 897 distance: nan
# Alignment 1 vs Alignment 898 distance: nan
# Alignment 1 vs Alignment 899 distance: nan
# Alignment 1 vs Alignment 900 distance: nan
# Alignment 1 vs Alignment 901 distance: nan
# Alignment 1 vs Alignment 902 distance: nan
# Alignment 1 vs Alignment 903 distance: nan
# Alignment 1 vs Alignment 904 distance: nan
# Alignment 1 vs Alignment 905 distance: nan
# Alignment 1 vs Alignment 906 distance: nan
# Alignment 1 vs Alignment 907 distance: nan
# Alignment 1 vs Alignment 908 distance: nan
# Alignment 1 vs Alignment 909 distance: nan
# Alignment 1 vs Alignment 910 distance: nan
# Alignment 1 vs Alignment 911 distance: nan
# Alignment 1 vs Alignment 912 distance: nan
# Alignment 1 vs Alignment 913 distance: nan
# Alignment 1 vs Alignment 914 distance: nan
# Alignment 1 vs Alignment 915 distance: nan
# Alignment 1 vs Alignment 916 distance: nan
# Alignment 1 vs Alignment 917 distance: nan
# Alignment 1 vs Alignment 918 distance: nan
# Alignment 1 vs Alignment 919 distance: nan
# Alignment 1 vs Alignment 920 distance: nan
# Alignment 1 vs Alignment 921 distance: nan
# Alignment 1 vs Alignment 922 distance: nan
# Alignment 1 vs Alignment 923 distance: nan
# Alignment 1 vs Alignment 924 distance: nan
# Alignment 1 vs Alignment 925 distance: nan
# Alignment 1 vs Alignment 926 distance: nan
# Alignment 1 vs Alignment 927 distance: nan
# Alignment 1 vs Alignment 928 distance: nan
# Alignment 1 vs Alignment 929 distance: nan
# Alignment 1 vs Alignment 930 distance: nan
# Alignment 1 vs Alignment 931 distance: nan
# Alignment 1 vs Alignment 932 distance: nan
# Alignment 1 vs Alignment 933 distance: nan
# Alignment 1 vs Alignment 934 distance: nan
# Alignment 1 vs Alignment 935 distance: nan
# Alignment 1 vs Alignment 936 distance: nan
# Alignment 1 vs Alignment 937 distance: nan
# Alignment 1 vs Alignment 938 distance: nan
# Alignment 1 vs Alignment 939 distance: nan
# Alignment 1 vs Alignment 940 distance: nan
# Alignment 1 vs Alignment 941 distance: nan
# Alignment 1 vs Alignment 942 distance: nan
# Alignment 1 vs Alignment 943 distance: nan
# Alignment 1 vs Alignment 944 distance: nan
# Alignment 1 vs Alignment 945 distance: nan
# Alignment 1 vs Alignment 946 distance: nan
# Alignment 1 vs Alignment 947 distance: nan
# Alignment 1 vs Alignment 948 distance: nan
# Alignment 1 vs Alignment 949 distance: nan
# Alignment 1 vs Alignment 950 distance: nan
# Alignment 1 vs Alignment 951 distance: nan
# Alignment 1 vs Alignment 952 distance: nan
# Alignment 1 vs Alignment 953 distance: nan
# Alignment 1 vs Alignment 954 distance: nan
# Alignment 1 vs Alignment 955 distance: nan
# Alignment 1 vs Alignment 956 distance: nan
# Alignment 1 vs Alignment 957 distance: nan
# Alignment 1 vs Alignment 958 distance: nan
# Alignment 1 vs Alignment 959 distance: nan
# Alignment 1 vs Alignment 960 distance: nan
# Alignment 1 vs Alignment 961 distance: nan
# Alignment 1 vs Alignment 962 distance: nan
# Alignment 1 vs Alignment 963 distance: nan
# Alignment 1 vs Alignment 964 distance: nan
# Alignment 1 vs Alignment 965 distance: nan
# Alignment 1 vs Alignment 966 distance: nan
# Alignment 1 vs Alignment 967 distance: nan
# Alignment 1 vs Alignment 968 distance: nan
# Alignment 1 vs Alignment 969 distance: nan
# Alignment 1 vs Alignment 970 distance: nan
# Alignment 1 vs Alignment 971 distance: nan
# Alignment 1 vs Alignment 972 distance: nan
# Alignment 1 vs Alignment 973 distance: nan
# Alignment 1 vs Alignment 974 distance: nan
# Alignment 1 vs Alignment 975 distance: nan
# Alignment 1 vs Alignment 976 distance: nan
# Alignment 1 vs Alignment 977 distance: nan
# Alignment 1 vs Alignment 978 distance: nan
# Alignment 1 vs Alignment 979 distance: nan
# Alignment 1 vs Alignment 980 distance: nan
# Alignment 1 vs Alignment 981 distance: nan
# Alignment 1 vs Alignment 982 distance: nan
# Alignment 1 vs Alignment 983 distance: nan
# Alignment 1 vs Alignment 984 distance: nan
# Alignment 1 vs Alignment 985 distance: nan
# Alignment 1 vs Alignment 986 distance: nan
# Alignment 1 vs Alignment 987 distance: nan
# Alignment 1 vs Alignment 988 distance: nan
# Alignment 1 vs Alignment 989 distance: nan
# Alignment 1 vs Alignment 990 distance: nan
# Alignment 1 vs Alignment 991 distance: nan
# Alignment 1 vs Alignment 992 distance: nan
# Alignment 1 vs Alignment 993 distance: nan
# Alignment 1 vs Alignment 994 distance: nan
# Alignment 1 vs Alignment 995 distance: nan
# Alignment 1 vs Alignment 996 distance: nan
# Alignment 1 vs Alignment 997 distance: nan
# Alignment 1 vs Alignment 998 distance: nan
# Alignment 1 vs Alignment 999 distance: nan
# Alignment 1 vs Alignment 1000 distance: nan
# Alignment 1 vs Alignment 1001 distance: nan
# Alignment 1 vs Alignment 1002 distance: nan
# Alignment 1 vs Alignment 1003 distance: nan
# Alignment 1 vs Alignment 1004 distance: nan
# Alignment 1 vs Alignment 1005 distance: nan
# Alignment 1 vs Alignment 1006 distance: nan
# Alignment 1 vs Alignment 1007 distance: nan
# Alignment 1 vs Alignment 1008 distance: nan
# Alignment 1 vs Alignment 1009 distance: nan
# Alignment 1 vs Alignment 1010 distance: nan
# Alignment 1 vs Alignment 1011 distance: nan
# Alignment 1 vs Alignment 1012 distance: nan
# Alignment 1 vs Alignment 1013 distance: nan
# Alignment 1 vs Alignment 1014 distance: nan
# Alignment 1 vs Alignment 1015 distance: nan
# Alignment 1 vs Alignment 1016 distance: nan
# Alignment 1 vs Alignment 1017 distance: nan
# Alignment 1 vs Alignment 1018 distance: nan
# Alignment 1 vs Alignment 1019 distance: nan
# Alignment 1 vs Alignment 1020 distance: nan
# Alignment 1 vs Alignment 1021 distance: nan
# Alignment 1 vs Alignment 1022 distance: nan
# Alignment 1 vs Alignment 1023 distance: nan
# Alignment 1 vs Alignment 1024 distance: nan
# Alignment 1 vs Alignment 1025 distance: nan
# Alignment 1 vs Alignment 1026 distance: nan
# Alignment 1 vs Alignment 1027 distance: nan
# Alignment 1 vs Alignment 1028 distance: nan
# Alignment 1 vs Alignment 1029 distance: nan
# Alignment 1 vs Alignment 1030 distance: nan
# Alignment 1 vs Alignment 1031 distance: nan
# Alignment 1 vs Alignment 1032 distance: nan
# Alignment 1 vs Alignment 1033 distance: nan
# Alignment 1 vs Alignment 1034 distance: nan
# Alignment 1 vs Alignment 1035 distance: nan
# Alignment 1 vs Alignment 1036 distance: nan
# Alignment 1 vs Alignment 1037 distance: nan
# Alignment 1 vs Alignment 1038 distance: nan
# Alignment 1 vs Alignment 1039 distance: nan
# Alignment 1 vs Alignment 1040 distance: nan
# Alignment 1 vs Alignment 1041 distance: nan
# Alignment 1 vs Alignment 1042 distance: nan
# Alignment 1 vs Alignment 1043 distance: nan
# Alignment 1 vs Alignment 1044 distance: nan
# Alignment 1 vs Alignment 1045 distance: nan
# Alignment 1 vs Alignment 1046 distance: nan
# Alignment 1 vs Alignment 1047 distance: nan
# Alignment 1 vs Alignment 1048 distance: nan
# Alignment 1 vs Alignment 1049 distance: nan
# Alignment 1 vs Alignment 1050 distance: nan
# Alignment 1 vs Alignment 1051 distance: nan
# Alignment 1 vs Alignment 1052 distance: nan
# Alignment 1 vs Alignment 1053 distance: nan
# Alignment 1 vs Alignment 1054 distance: nan
# Alignment 1 vs Alignment 1055 distance: nan
# Alignment 1 vs Alignment 1056 distance: nan
# Alignment 1 vs Alignment 1057 distance: nan
# Alignment 1 vs Alignment 1058 distance: nan
# Alignment 1 vs Alignment 1059 distance: nan
# Alignment 1 vs Alignment 1060 distance: nan
# Alignment 1 vs Alignment 1061 distance: nan
# Alignment 1 vs Alignment 1062 distance: nan
# Alignment 1 vs Alignment 1063 distance: nan
# Alignment 1 vs Alignment 1064 distance: nan
# Alignment 1 vs Alignment 1065 distance: nan
# Alignment 1 vs Alignment 1066 distance: nan
# Alignment 1 vs Alignment 1067 distance: nan
# Alignment 1 vs Alignment 1068 distance: nan
# Alignment 1 vs Alignment 1069 distance: nan
# Alignment 1 vs Alignment 1070 distance: nan
# Alignment 1 vs Alignment 1071 distance: nan
# Alignment 1 vs Alignment 1072 distance: nan
# Alignment 1 vs Alignment 1073 distance: nan
# Alignment 1 vs Alignment 1074 distance: nan
# Alignment 1 vs Alignment 1075 distance: nan
# Alignment 1 vs Alignment 1076 distance: nan
# Alignment 1 vs Alignment 1077 distance: nan
# Alignment 1 vs Alignment 1078 distance: nan
# Alignment 1 vs Alignment 1079 distance: nan
# Alignment 1 vs Alignment 1080 distance: nan
# Alignment 1 vs Alignment 1081 distance: nan
# Alignment 1 vs Alignment 1082 distance: nan
# Alignment 1 vs Alignment 1083 distance: nan
# Alignment 1 vs Alignment 1084 distance: nan
# Alignment 1 vs Alignment 1085 distance: nan
# Alignment 1 vs Alignment 1086 distance: nan
# Alignment 1 vs Alignment 1087 distance: nan
# Alignment 1 vs Alignment 1088 distance: nan
# Alignment 1 vs Alignment 1089 distance: nan
# Alignment 1 vs Alignment 1090 distance: nan
# Alignment 1 vs Alignment 1091 distance: nan
# Alignment 1 vs Alignment 1092 distance: nan
# Alignment 1 vs Alignment 1093 distance: nan
# Alignment 1 vs Alignment 1094 distance: nan
# Alignment 1 vs Alignment 1095 distance: nan
# Alignment 1 vs Alignment 1096 distance: nan
# Alignment 1 vs Alignment 1097 distance: nan
# ...
# Alignment 3 vs Alignment 125435 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125436 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125437 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125438 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125439 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125440 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125441 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125442 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125443 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125444 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125445 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125446 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125447 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125448 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125449 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125450 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125451 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125452 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125453 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125454 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125455 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125456 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125457 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125458 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125459 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125460 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125461 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125462 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125463 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125464 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125465 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125466 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125467 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125468 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125469 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125470 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125471 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125472 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125473 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125474 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125475 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125476 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125477 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125478 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125479 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125480 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125481 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125482 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125483 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125484 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125485 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125486 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125487 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125488 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125489 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125490 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125491 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125492 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125493 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125494 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125495 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125496 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125497 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125498 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125499 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125500 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125501 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125502 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125503 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125504 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125505 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125506 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125507 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125508 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125509 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125510 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125511 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125512 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125513 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125514 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125515 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125516 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125517 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125518 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125519 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125520 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125521 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125522 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125523 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125524 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125525 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125526 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125527 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125528 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125529 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125530 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125531 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125532 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125533 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125534 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125535 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125536 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125537 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125538 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125539 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125540 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125541 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125542 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125543 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125544 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125545 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125546 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125547 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125548 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125549 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125550 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125551 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125552 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125553 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125554 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125555 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125556 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125557 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125558 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125559 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125560 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125561 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125562 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125563 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125564 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125565 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125566 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125567 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125568 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125569 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125570 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125571 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125572 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125573 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125574 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125575 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125576 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125577 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125578 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125579 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125580 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125581 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125582 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125583 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125584 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125585 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125586 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125587 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125588 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125589 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125590 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125591 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125592 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125593 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125594 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125595 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125596 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125597 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125598 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125599 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125600 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125601 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125602 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125603 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125604 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125605 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125606 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125607 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125608 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125609 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125610 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125611 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125612 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125613 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125614 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125615 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125616 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125617 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125618 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125619 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125620 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125621 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125622 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125623 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125624 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125625 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125626 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125627 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125628 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125629 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125630 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125631 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125632 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125633 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125634 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125635 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125636 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125637 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125638 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125639 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125640 distance: 0.8239592165010822
# Alignment 3 vs Alignment 125641 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125642 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125643 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125644 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125645 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125646 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125647 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125648 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125649 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125650 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125651 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125652 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125653 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125654 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125655 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125656 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125657 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125658 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125659 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125660 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125661 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125662 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125663 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125664 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125665 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125666 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125667 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125668 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125669 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125670 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125671 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125672 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125673 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125674 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125675 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125676 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125677 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125678 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125679 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125680 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125681 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125682 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125683 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125684 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125685 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125686 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125687 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125688 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125689 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125690 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125691 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125692 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125693 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125694 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125695 distance: 1.2070784343255752
# Alignment 3 vs Alignment 125696 distance: 1.2070784343255752
